# %%
import pandas as pd

# %%
df=pd.read_csv("/content/medallists.csv")

# %%
print(df.head())
# Out:
#    medal_date    medal_type  medal_code             name  gender country_code  \
# 0  2024-07-27    Gold Medal         1.0  EVENEPOEL Remco    Male          BEL
# 1  2024-07-27  Silver Medal         2.0    GANNA Filippo    Male          ITA
# 2  2024-07-27  Bronze Medal         3.0    van AERT Wout    Male          BEL
# 3  2024-07-27    Gold Medal         1.0      BROWN Grace  Female          AUS
# 4  2024-07-27  Silver Medal         2.0   HENDERSON Anna  Female          GBR
#
#          country   country_long nationality_code    nationality  ... team  \
# 0        Belgium        Belgium              BEL        Belgium  ...  NaN
# 1          Italy          Italy              ITA          Italy  ...  NaN
# 2        Belgium        Belgium              BEL        Belgium  ...  NaN
# 3      Australia      Australia              AUS      Australia  ...  NaN
# 4  Great Britain  Great Britain              GBR  Great Britain  ...  NaN
#
# ...

# %%
print(df.isnull().sum())
# Out:
# medal_date            0
# medal_type            0
# medal_code            1
# name                  0
# gender                0
# country_code          0
# country               0
# country_long          0
# nationality_code      1
# nationality           1
# nationality_long      1
# team                760
# team_gender         760
# discipline            0
# event                 0
# event_type            0
# url_event            21
# birth_date            0
# code_athlete          0
# code_team           760
# is_medallist          0
# dtype: int64

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2315 entries, 0 to 2314
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   medal_date        2315 non-null   object
#  1   medal_type        2315 non-null   object
#  2   medal_code        2314 non-null   float64
#  3   name              2315 non-null   object
#  4   gender            2315 non-null   object
#  5   country_code      2315 non-null   object
#  6   country           2315 non-null   object
#  7   country_long      2315 non-null   object
#  8   nationality_code  2314 non-null   object
#  9   nationality       2314 non-null   object
#  10  nationality_long  2314 non-null   object
#  11  team              1555 non-null   object
#  12  team_gender       1555 non-null   object
#  13  discipline        2315 non-null   object
#  14  event             2315 non-null   object
#  15  event_type        2315 non-null   object
# ...

# %%
print(df.describe())
# Out:
#         medal_code  code_athlete
# count  2314.000000  2.315000e+03
# mean      2.023336  1.893321e+06
# std       0.820390  2.628276e+05
# min       1.000000  1.532872e+06
# 25%       1.000000  1.896552e+06
# 50%       2.000000  1.924464e+06
# 75%       3.000000  1.950498e+06
# max       3.000000  4.980004e+06

# %%
print(df.columns)
# Out:
# Index(['medal_date', 'medal_type', 'medal_code', 'name', 'gender',
#        'country_code', 'country', 'country_long', 'nationality_code',
#        'nationality', 'nationality_long', 'team', 'team_gender', 'discipline',
#        'event', 'event_type', 'url_event', 'birth_date', 'code_athlete',
#        'code_team', 'is_medallist'],
#       dtype='object')

# %%
country_medals = df.groupby("country")["medal_type"].count()

print(country_medals)
# Out:
# country
# AIN                6
# Albania            2
# Algeria            3
# Argentina         19
# Armenia            4
#                 ...
# Uganda             2
# Ukraine           16
# United States    330
# Uzbekistan        13
# Zambia             1
# Name: medal_type, Length: 92, dtype: int64

# %%
gold_by_country = gold_df.groupby("country")["medal_type"].count()

print(gold_by_country.sort_values(ascending=False).head(10))
# Out:
# country
# United States    134
# China             71
# Netherlands       67
# France            53
# Great Britain     40
# Spain             40
# Australia         33
# Italy             31
# Japan             27
# New Zealand       26
# Name: medal_type, dtype: int64

# %%
gender_count = df.groupby("gender")["medal_type"].count()
print(gender_count)
# Out:
# gender
# Female    1162
# Male      1153
# Name: medal_type, dtype: int64

# %%
athlete_medals = df.groupby("name")["medal_type"].count()

print(athlete_medals.sort_values(ascending=False).head(10))
# Out:
# name
# ZHANG Yufei           6
# MARCHAND Leon         5
# McKEOWN Kaylee        5
# O'CALLAGHAN Mollie    5
# SMITH Regan           5
# HUSKE Torri           5
# LEDECKY Katie         4
# DOUGLASS Kate         4
# YANG Junxuan          4
# ANDRADE Rebeca        4
# Name: medal_type, dtype: int64

# %%
import matplotlib.pyplot as plt

country_medals.sort_values(ascending=False).head(10).plot(kind="bar")

plt.title("Top 10 Countries by Medal Count")
plt.xlabel("Country")
plt.ylabel("Total Medals")
plt.show()
